# %%
import pandas as pd

# %%
df = pd.read_pickle('QUIZZIZ_18K_QUIZ_BANK_MULTIPLE_CHOICE.pkl')

# %%
time_per_q = input('Enter duration per question')
# Out:
# Enter duration per question 20

# %%
quiz_length = int(input('Enter number of questions for this quiz; must be a whole number; like 20!'))
# Out:
# Enter number of questions for this quiz; must be a whole number; like 20! 20

# %%
file_xlsx_name = input('Enter File Name')
# Out:
# Enter File Name Quizziz_03

# %%
df['Time in seconds'] = time_per_q

# %%
quiz = df.sample(1000).drop_duplicates(['Option 5']).reset_index(drop=True).head(quiz_length)

# %%
quiz.to_excel(f'{file_xlsx_name}.xlsx', encoding='utf-8', index=False)

# %%
test = pd.read_pickle('STAGE_02_18K_quiz.pkl')

# %%
print(test['QUESTION'].iloc[343])
print(test['ar'].iloc[343])
# Out:
# Good practices in the provision of services endeavour to _ _ _ _ _ _ _ these challenges .
# والممارساتُ الجيدة في تقديم الخدمات تسعى إلى التغلب على هذه التحَدِّيات.

# %%
test['VERB'].iloc[343]
# Out:
# 'address'

# %%
test = pd.read_pickle('THINK_TANKS_UN_CORPUS_INTERSECTION_VERB_NOUN_PAT.pkl')

# %%
= dict(test['PAT_LEMMA'].value_counts())
# Out:
# {'develop country': 33845,
#  'take place': 10517,
#  'take note': 9440,
#  'take into account': 8328,
#  'provide information': 4836,
#  'make a statement': 4088,
#  'displace person': 3894,
#  'work group': 3834,
#  'increase number': 3642,
#  'give the floor': 3551,
#  'take action': 3435,
#  'express concern': 3175,
#  'be a need': 2948,
#  'draw attention': 2708,
#  'provide support': 2619,
#  'have the right': 2520,
#  'have access': 2503,
#  'stress the importance': 2455,
#  'enter into force': 2355,
#  'raise awareness': 2306,
#  'put in place': 2249,
#  'base violence': 2037,
#  'provide assistance': 2003,
#  'take part': 1980,
#  'play an important role': 1968,
#  'address the issue': 1819,
#  'take step': 1817,
#  'emphasize the importance': 1675,
#  'develop state': 1668,
#  'take into consideration': 1651,
#  'make recommendation': 1588,
#  'take measure': 1555,
#  'organize crime': 1504,
#  'base approach': 1471,
#  'emphasize the need': 1408,
# ...
